# %%
import numpy as np
import matplotlib.pyplot as plt
import h5py

# %%
with h5py.File("results_opt_nograd_All.h5", "r") as f:
    params = f['iters'][:]

# %%
print(params)
# Out:
# [10 20 30]

# %%
with h5py.File("data_stiff.h5") as f:
    
    x_data = f['phi_vec'][:]
    y_data = f['result_loss_stiff'][:]

# %%
fig, ax = plt.subplots(figsize=(12, 10))
plt.rcParams['text.usetex'] = True
plt.rcParams['font.family'] = 'serif'
plt.plot(x_data, y_data, linewidth=3)
plt.yscale('log')
plt.grid()
ax.tick_params(axis='y', labelsize=32)
ax.tick_params(axis='x', labelsize=32)
plt.ylabel(r'$\Phi$', fontsize=50)
plt.xlabel(r'$V_0$', fontsize=50)
plt.tight_layout()
plt.savefig("loss_v0.png")
